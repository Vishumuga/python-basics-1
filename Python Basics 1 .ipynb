# %% [markdown]
# #**What is python?**
# - Python is a programing lanuage thats used to perform data analysis, including  stastical analysis, data visuualization and data prepration.
# - python is an interpreted, object-orianted,high-lavel programing language with dynamic semantics.
# - python is programing language that is widely in web application, software develapment, data science and machine learning.
# #**Why python?**
# - Easy to learn, easy to understand,easy to connect with the database.
# - Its simplysicty, community, support, rich ecoystem of libraries and tools.
# - Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).
# - Python has a simple syntax similar to the English language.
# - Python has syntax that allows developers to write programs with fewer lines than some other programming languages.
# - Python runs on an interpreter system, meaning that code can be executed as soon as it is
# written. This means that prototyping can be very quick.
# - Python can be treated in a procedural way, an object-oriented way or a functional way
# #**History of python?**
# - Python laid its foundation in the late 1980s.
# - The implementation of Python was started in
# December 1989 by Guido Van Rossum at CWI
# in Netherland.
# - In February 1991, Guido Van
# Rossum published the code (labeled version0.9.0) to alt sources.
# - In 1994, Python 1.0 was released with new
# features like lambda, map, filter, and reduce.
# - Python 2.0 added new features such as list
# comprehensions, garbage collection systems.
# - On December 3, 2008, Python 3.0 (also called
# "Py3K") was released. It was designed to rectify
# the fundamental flaw of the language.
# #**comments with example?**
# - comments in python are used to add Explanatory  notes to the code. they help in making the code more reqdable and understandable but do not affect the execution of the program.
# #There are two types of comments in Python
# -1:- Single-line comments.
# -2:- Multi-line comments.
#
# #**single line comments**:-
# - These comments are used to explain or clarify a single line of code.
# - In many programming languages, a single-line comment starts with a special character or keyword.
# - syntax:-In Python, single-line comments begin with the hash symbol(#).
# ##This is a single line comment
# print("hello world") # this prints greeting massage.
# ##This is a single-line comment
# x=10 # assigns 10 to variable x

# %%
# this is a single-line comment in Python
print("Hello, world!")  # this is an inl.
# Out:
# Hello, world!

# %% [markdown]
# ##**Multi line comments**:
# - this comments span mulitiple lines and are generally  used for longer explanations documentions.python doest have a specific syntax for multi-line comments, but you can use.
# - triple quotes ("""or""") to simulata multi-line comments. althrough triple quotes are typically used for dpcstrings, they can also be used for comments if they are not assigned to a variable.

# %%
'''
"This is a multi-line comment in Python".
It can span multiple lines.
"you can use it do explain a section of your code".
'''
print("this is a multi line comment example.")
# Out:
# this is a multi line comment example.

# %% [markdown]
# #**keywords with example?**
# -keyword is reserved words that have special meaning and are part of the language syntax. these keywords cannot be used as identifiers(such as variable names, function namesor class names)
# #example
# -False,
# None,
# True,
# and,
# as,
# assert,
# async,
# await,
# break,
# class,
# continue,
# def,
# del,
# elif,
# else,
# except,
# finally,
# for,
# from,
# global,
# if,
# import,
# in,
# is,
# lambda,
# nonlocal,
# not,
# or,
# pass,
# raise,
# return,
# try,
# while,
# with,
# yield.
#
# #**what is variable and rules?**
# -storing of an element. it acts as a container for data,and this data can be of various types such as number, sring,list, and ,ore. variables allow you to store and manipulate data during the execution of a program.
# #Rules
# -variable are created using alpha numaric charactrs[a-Z,a-z,0-9]
# -variable name cannot start with digit
# -we can not able to use special character to creat avariable expect(-) underscore
# -we cannot able to use keywords to creat a variale (if,else,for,etc)
# -varibale is a case-sensitive (Age and age ara deffrent ).
# #**valid and invalid variable example?(store numaric values)**
# -**valid:**

# %%
In[]:
# Example 1: Variable starts with a letter
age = 25
print(age)  # Output: 25

# Example 2: Variable contains letters and numbers
name_123 = "Alice"
print(name_123)  # Output: Alice

# Example 3: Variable starts with an underscore
_score = 100
print(_score)  # Output: 100

# Example 4: Variable starts with a letter and contains a number
height_5 = 5.6
print(height_5)  # Output: 5.6

# Example 5: Camel case variable
tempVariable = 42
print(tempVariable)  # Output: 42

# Example 6: Variable starts with a letter and contains a number
value_1 = 50
print(value_1)  # Output: 50

# Example 7: Variable with an underscore
user_name = "John"
print(user_name)  # Output: John

# Example 8: Variable with a number in the second position
x1 = 10
print(x1)  # Output
# Out:
# 25
# Alice
# 100
# 5.6
# 42
# 50
# John
# 10

# %% [markdown]
# **Invalid**

# %%
# Example 1: Starts with a number (invalid)
# 1st_name = "Bob"  # SyntaxError: invalid syntax

# Example 2: Contains a hyphen (invalid)
# total-amount = 100  # SyntaxError: invalid syntax

# Example 3: Uses a Python keyword (invalid)
# for = 10  # SyntaxError: cannot assign to keyword

# Example 4: Starts with a number (invalid)
# 123abc = "Hello"  # SyntaxError: invalid syntax

# Example 5: Contains a space (invalid)
# total amount = 200  # SyntaxError: invalid syntax

# Example 6: Contains a special character '@' (invalid)
# @variable = 50  # SyntaxError: invalid syntax

# Example 7: Uses a Python keyword (invalid)
# global = 100  # SyntaxError: cannot assign to keyword

# Example 8: Uses a Python keyword (invalid)
# if_value = 20  # SyntaxError: cannot assign to keyword

# Example 9: Contains a special character '$' (invalid)
# variable$ = 5  # SyntaxError: invalid syntax

# Example 10: Uses a Python keyword (invalid)
# True = 10  # SyntaxError: cannot assign to keyword
